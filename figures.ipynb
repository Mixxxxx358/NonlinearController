# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x = np.array([-2,-1,0,1,2,3,4])
y = np.array([0.3,0.3,0.4,0.4,0.5,0.5,0.5])-0.3

a = np.polyfit(x, y, 6)
p = np.poly1d(a)
pd = np.poly1d(p.deriv())

xp = np.linspace(-1,3,100)

minX = 0.1; max

fig = plt.figure(figsize=(14,8))
ax = plt.axes()

ax.plot(xp, p(xp))

slope = pd(2.5)
xdiff = 0.2
ax.plot([2.5-xdiff, 2.5+xdiff], [p(2.5)-xdiff*slope, p(2.5)+xdiff*slope], 'r-')
ax.plot([2.5, 2.5], [0., p(2.5)], 'k--', lw=2)

# xd = [0.5, 1.0, 1.5, 2.0]
# for xi in xd:
#     slope = pd(xi)
#     ax.plot([xi-xdiff, xi+xdiff], [p(xi)-xdiff*slope, p(xi)+xdiff*slope], 'r-')
#     ax.plot([xi, xi], [0., p(xi)], 'k--', lw=2)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.xlim([0,3])
plt.ylim([0.,0.3])

plt.savefig("Figures/myimg.svg")

# %%
p
# Out:
# poly1d([ 0.00208333, -0.01291667,  0.00625   ,  0.06458333, -0.05833333,
#        -0.00166667,  0.1       ])
